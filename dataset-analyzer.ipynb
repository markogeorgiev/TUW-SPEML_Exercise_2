# %%
import os
import pandas as pd

FOLDER_PATH = "dataset\MIA_SDG_Exercise"
SYNTHETIC_FILES = [f"synthetic_data{i}.csv" for i in range(1, 5)]
TEST_FILES = ["test_data_with_outliers.csv", "test_data_wto_outliers.csv"]

ALL_FILES = SYNTHETIC_FILES + TEST_FILES


def analyze_dataset(df, name):
    print(f"\n{'=' * 40}\nDataset: {name}\n{'=' * 40}")

    # 1. Shape
    print(f"Shape: {df.shape}")

    # 2. Missing values
    missing = df.isnull().sum()
    missing_pct = df.isnull().mean() * 100
    missing_summary = pd.DataFrame({
        'MissingCount': missing,
        'MissingPct': missing_pct
    }).sort_values('MissingCount', ascending=False)
    print("\nMissing Values:")
    print(missing_summary[missing_summary.MissingCount > 0])

    # 3. Data types
    print("\nData Types:")
    print(df.dtypes)

    # 4. Number of unique values
    unique_counts = df.nunique().sort_values(ascending=False)
    print("\nDistinct Values per Column:")
    print(unique_counts)

    # 5. Top 5 frequent values per column
    print("\nTop-5 Frequent Values per Column:")
    for col in df.columns:
        print(f"\n[{col}]")
        print(df[col].value_counts(dropna=False).head(5))

    # 6. Summary statistics for numerical data
    print("\nNumerical Summary:")
    print(df.describe(include=[float, int]))

    # 7. Summary statistics for categorical data
    print("\nCategorical Summary:")
    print(df.describe(include=[object, "category"]))


def main():
    for file_name in ALL_FILES:
        path = os.path.join(FOLDER_PATH, file_name)
        try:
            df = pd.read_csv(path)
            analyze_dataset(df, file_name)
        except Exception as e:
            print(f"Error reading {file_name}: {e}")


if __name__ == "__main__":
    main()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\M'
# <>:4: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\marko\AppData\Local\Temp\ipykernel_24244\1070705000.py:4: SyntaxWarning: invalid escape sequence '\M'
#   FOLDER_PATH = "dataset\MIA_SDG_Exercise"
# ========================================
# Dataset: synthetic_data1.csv
# ========================================
# Shape: (4800, 31)
#
# Missing Values:
#                      MissingCount  MissingPct
# body_weight                  4640   96.666667
# hba1c_result                 3928   81.833333
# provider_specialty           2417   50.354167
# insurance_type_code          1885   39.270833
# ethnic_group                  115    2.395833
#
# Data Types:
# lab_test_count          int64
# primary_diagnosis      object
# secondary_diagnosis    object
# tertiary_diagnosis     object
# medication_count        int64
# inpatient_visits        int64
# stay_duration_days      int64
# age_range              object
# provider_specialty     object
# insurance_type_code    object
# diagnosis_count         int64
# exit_status_code        int64
# procedure_count         int64
# entry_type_code         int64
# drug_013               object
# entry_origin_code       int64
# ethnic_group           object
# outpatient_visits       int64
# emergency_visits        int64
# sex                    object
# drug_014               object
# hba1c_result           object
# med_change_flag        object
# drug_008               object
# drug_015               object
# on_diabetes_med        object
# drug_017               object
# drug_020               object
# drug_006               object
# body_weight            object
# readmission_status     object
# dtype: object
#
# Distinct Values per Column:
# tertiary_diagnosis     324
# primary_diagnosis      316
# secondary_diagnosis    308
# lab_test_count         101
# medication_count        55
# provider_specialty      39
# exit_status_code        27
# entry_origin_code       21
# insurance_type_code     16
# diagnosis_count         15
# stay_duration_days      15
# procedure_count          9
# entry_type_code          9
# inpatient_visits         8
# body_weight              7
# outpatient_visits        6
# age_range                5
# emergency_visits         5
# ethnic_group             5
# drug_013                 4
# drug_014                 4
# drug_008                 4
# drug_017                 4
# drug_006                 4
# drug_020                 4
# drug_015                 4
# hba1c_result             3
# readmission_status       3
# sex                      2
# med_change_flag          2
# on_diabetes_med          2
# dtype: int64
#
# Top-5 Frequent Values per Column:
#
# [lab_test_count]
# lab_test_count
# 46    109
# 42    105
# 41    105
# 45    104
# 47     97
# Name: count, dtype: int64
#
# [primary_diagnosis]
# primary_diagnosis
# DX310    314
# DX297    288
# DX600    214
# DX293    164
# DX363    125
# Name: count, dtype: int64
#
# [secondary_diagnosis]
# secondary_diagnosis
# DX166    322
# DX310    298
# DX110    271
# DX309    245
# DX460    159
# Name: count, dtype: int64
#
# [tertiary_diagnosis]
# tertiary_diagnosis
# DX110    525
# DX287    392
# DX166    233
# DX310    228
# DX309    205
# Name: count, dtype: int64
#
# [medication_count]
# medication_count
# 10    265
# 13    264
# 11    247
# 12    247
# 14    234
# Name: count, dtype: int64
#
# [inpatient_visits]
# inpatient_visits
#  0    2118
#  1    1516
#  2     577
# -1     305
#  3     207
# Name: count, dtype: int64
#
# [stay_duration_days]
# stay_duration_days
# 2    871
# 3    773
# 4    676
# 5    552
# 1    528
# Name: count, dtype: int64
#
# [age_range]
# age_range
# 60-80    2198
# 40-60    1337
# 80+       949
# 20-40     271
# 0-20       45
# Name: count, dtype: int64
#
# [provider_specialty]
# provider_specialty
# NaN                   2417
# Internal Medicine      641
# Emergency Medicine     375
# Family Practice        335
# Cardiologist           243
# Name: count, dtype: int64
#
# [insurance_type_code]
# insurance_type_code
# NaN           1885
# provider_c    1492
# provider_a     327
# provider_b     244
# self_pay       237
# Name: count, dtype: int64
#
# [diagnosis_count]
# diagnosis_count
# 7    957
# 8    865
# 6    798
# 9    699
# 5    433
# Name: count, dtype: int64
#
# [exit_status_code]
# exit_status_code
# 1    981
# 0    763
# 2    730
# 3    560
# 4    407
# Name: count, dtype: int64
#
# [procedure_count]
# procedure_count
#  0    1439
#  1    1333
#  2     933
#  3     484
# -1     238
# Name: count, dtype: int64
#
# [entry_type_code]
# entry_type_code
# 1    2515
# 2     872
# 3     852
# 6     283
# 5     263
# Name: count, dtype: int64
#
# [drug_013]
# drug_013
# absent      2199
# constant    1503
# decrease     578
# increase     520
# Name: count, dtype: int64
#
# [entry_origin_code]
# entry_origin_code
# 3    542
# 2    528
# 4    525
# 1    503
# 5    465
# Name: count, dtype: int64
#
# [ethnic_group]
# ethnic_group
# Caucasian          3625
# AfricanAmerican     864
# NaN                 115
# Hispanic             85
# Other                81
# Name: count, dtype: int64
#
# [outpatient_visits]
# outpatient_visits
#  0    2650
#  1    1395
# -1     379
#  2     317
#  3      52
# Name: count, dtype: int64
#
# [emergency_visits]
# emergency_visits
#  0    3403
#  1    1105
# -1     202
#  2      88
#  3       2
# Name: count, dtype: int64
#
# [sex]
# sex
# Female    2518
# Male      2282
# Name: count, dtype: int64
#
# [drug_014]
# drug_014
# absent      3821
# constant     916
# increase      36
# decrease      27
# Name: count, dtype: int64
#
# [hba1c_result]
# hba1c_result
# NaN              3928
# high              384
# normal            257
# moderate high     231
# Name: count, dtype: int64
#
# [med_change_flag]
# med_change_flag
# No     2682
# Yes    2118
# Name: count, dtype: int64
#
# [drug_008]
# drug_008
# absent      4263
# constant     491
# decrease      26
# increase      20
# Name: count, dtype: int64
#
# [drug_015]
# drug_015
# absent      4268
# constant     459
# increase      52
# decrease      21
# Name: count, dtype: int64
#
# [on_diabetes_med]
# on_diabetes_med
# Yes    3631
# No     1169
# Name: count, dtype: int64
#
# [drug_017]
# drug_017
# absent      4476
# constant     307
# increase      14
# decrease       3
# Name: count, dtype: int64
#
# [drug_020]
# drug_020
# absent      4600
# constant     175
# increase      19
# decrease       6
# Name: count, dtype: int64
#
# [drug_006]
# drug_006
# absent      4428
# constant     361
# increase       8
# decrease       3
# Name: count, dtype: int64
#
# [body_weight]
# body_weight
# NaN          4640
# [75-100)       70
# [100-125)      44
# [50-75)        39
# [125-150)       3
# Name: count, dtype: int64
#
# [readmission_status]
# readmission_status
# not_readmitted      2511
# readmitted_late     1767
# readmitted_early     522
# Name: count, dtype: int64
#
# Numerical Summary:
#        lab_test_count  medication_count  inpatient_visits  stay_duration_days  \
# count     4800.000000       4800.000000       4800.000000         4800.000000
# mean        43.245833         16.247083          0.690208            4.362917
# std         19.290801          8.471013          1.032332            2.912483
# min          1.000000          1.000000         -1.000000            0.000000
# 25%         30.000000         10.000000          0.000000            2.000000
# 50%         43.000000         15.000000          0.000000            4.000000
# 75%         57.000000         21.000000          1.000000            6.000000
# max        101.000000         62.000000          6.000000           14.000000
#
#        diagnosis_count  exit_status_code  procedure_count  entry_type_code  \
# count      4800.000000       4800.000000      4800.000000      4800.000000
# mean          7.372500          3.570417         1.286250         2.064583
# std           1.998539          3.795628         1.469896         1.486200
# min           1.000000          0.000000        -1.000000         0.000000
# 25%           6.000000          1.000000         0.000000         1.000000
# 50%           7.000000          2.000000         1.000000         1.000000
# 75%           9.000000          5.000000         2.000000         3.000000
# max          15.000000         28.000000         7.000000         8.000000
#
#        entry_origin_code  outpatient_visits  emergency_visits
# count        4800.000000        4800.000000       4800.000000
# mean            5.767917           0.382083          0.226042
# std             4.185913           0.780207          0.546207
# min             0.000000          -1.000000         -1.000000
# 25%             3.000000           0.000000          0.000000
# 50%             5.000000           0.000000          0.000000
# 75%             8.000000           1.000000          0.000000
# max            20.000000           4.000000          3.000000
#
# Categorical Summary:
#        primary_diagnosis secondary_diagnosis tertiary_diagnosis age_range  \
# count               4800                4800               4800      4800
# unique               316                 308                324         5
# top                DX310               DX166              DX110     60-80
# freq                 314                 322                525      2198
#
#        provider_specialty insurance_type_code drug_013 ethnic_group     sex  \
# count                2383                2915     4800         4685    4800
# unique                 39                  16        4            5       2
# top     Internal Medicine          provider_c   absent    Caucasian  Female
# freq                  641                1492     2199         3625    2518
#
#        drug_014 hba1c_result med_change_flag drug_008 drug_015  \
# count      4800          872            4800     4800     4800
# unique        4            3               2        4        4
# top      absent         high              No   absent   absent
# freq       3821          384            2682     4263     4268
#
#        on_diabetes_med drug_017 drug_020 drug_006 body_weight  \
# count             4800     4800     4800     4800         160
# unique               2        4        4        4           7
# top                Yes   absent   absent   absent    [75-100)
# freq              3631     4476     4600     4428          70
#
#        readmission_status
# count                4800
# unique                  3
# top        not_readmitted
# freq                 2511
#
# ========================================
# Dataset: synthetic_data2.csv
# ========================================
# Shape: (4800, 31)
#
# Missing Values:
#                      MissingCount  MissingPct
# hba1c_result                 3479   72.479167
# max_glucose_level            3375   70.312500
# insurance_type_code          1396   29.083333
# provider_specialty            669   13.937500
# ethnic_group                  524   10.916667
#
# Data Types:
# lab_test_count          int64
# secondary_diagnosis    object
# primary_diagnosis      object
# tertiary_diagnosis     object
# medication_count        int64
# stay_duration_days      int64
# inpatient_visits        int64
# age_range              object
# provider_specialty     object
# exit_status_code        int64
# insurance_type_code    object
# diagnosis_count         int64
# procedure_count         int64
# drug_013               object
# entry_type_code         int64
# entry_origin_code       int64
# ethnic_group           object
# outpatient_visits       int64
# emergency_visits        int64
# sex                    object
# med_change_flag        object
# drug_014               object
# drug_008               object
# hba1c_result           object
# drug_015               object
# on_diabetes_med        object
# drug_017               object
# drug_006               object
# drug_020               object
# max_glucose_level      object
# readmission_status     object
# dtype: object
#
# Distinct Values per Column:
# primary_diagnosis      378
# tertiary_diagnosis     368
# secondary_diagnosis    356
# lab_test_count         100
# medication_count        66
# provider_specialty      48
# exit_status_code        22
# outpatient_visits       17
# emergency_visits        17
# insurance_type_code     16
# inpatient_visits        15
# stay_duration_days      14
# entry_origin_code       13
# diagnosis_count         11
# entry_type_code          9
# procedure_count          9
# age_range                5
# ethnic_group             5
# drug_013                 4
# drug_008                 4
# drug_014                 4
# drug_017                 4
# drug_015                 4
# drug_020                 4
# drug_006                 4
# max_glucose_level        3
# hba1c_result             3
# readmission_status       3
# med_change_flag          2
# sex                      2
# on_diabetes_med          2
# dtype: int64
#
# Top-5 Frequent Values per Column:
#
# [lab_test_count]
# lab_test_count
# 1     119
# 43    109
# 49     97
# 44     96
# 47     92
# Name: count, dtype: int64
#
# [secondary_diagnosis]
# secondary_diagnosis
# DX310    36
# DX166    35
# DX309    32
# DX110    29
# DX372    28
# Name: count, dtype: int64
#
# [primary_diagnosis]
# primary_diagnosis
# DX310    283
# DX297    169
# DX600    146
# DX363    145
# DX309    103
# Name: count, dtype: int64
#
# [tertiary_diagnosis]
# tertiary_diagnosis
# DX306     27
# DX_UNK    24
# DX135     24
# DX455     23
# DX456     22
# Name: count, dtype: int64
#
# [medication_count]
# medication_count
# 11    247
# 13    220
# 14    219
# 16    215
# 12    215
# Name: count, dtype: int64
#
# [stay_duration_days]
# stay_duration_days
# 2    639
# 3    586
# 1    545
# 4    469
# 5    408
# Name: count, dtype: int64
#
# [inpatient_visits]
# inpatient_visits
# 0    2576
# 1     786
# 2     319
# 3     168
# 4     133
# Name: count, dtype: int64
#
# [age_range]
# age_range
# 60-80    1952
# 40-60    1097
# 80+      1034
# 20-40     434
# 0-20      283
# Name: count, dtype: int64
#
# [provider_specialty]
# provider_specialty
# NaN                   669
# Internal Medicine     222
# Emergency Medicine    177
# Family Practice       157
# Cardiologist          132
# Name: count, dtype: int64
#
# [exit_status_code]
# exit_status_code
# 1     1659
# 3      506
# 6      442
# 18     178
# 2      151
# Name: count, dtype: int64
#
# [insurance_type_code]
# insurance_type_code
# NaN             1396
# provider_c      1032
# provider_a       257
# self_pay         257
# managed_care     227
# Name: count, dtype: int64
#
# [diagnosis_count]
# diagnosis_count
# 9    571
# 5    481
# 8    440
# 4    437
# 6    424
# Name: count, dtype: int64
#
# [procedure_count]
# procedure_count
# 0    2249
# 1     964
# 2     593
# 3     437
# 6     225
# Name: count, dtype: int64
#
# [drug_013]
# drug_013
# absent      2204
# constant    1524
# decrease     578
# increase     494
# Name: count, dtype: int64
#
# [entry_type_code]
# entry_type_code
# 1    1246
# 3     720
# 2     695
# 6     415
# 5     413
# Name: count, dtype: int64
#
# [entry_origin_code]
# entry_origin_code
# 7     1692
# 1     1207
# 17     510
# 4      196
# 6      168
# Name: count, dtype: int64
#
# [ethnic_group]
# ethnic_group
# Caucasian          1826
# AfricanAmerican     911
# NaN                 524
# Asian               518
# Other               515
# Name: count, dtype: int64
#
# [outpatient_visits]
# outpatient_visits
# 0    3334
# 1     386
# 2     164
# 3     127
# 4     102
# Name: count, dtype: int64
#
# [emergency_visits]
# emergency_visits
# 0    3349
# 1     360
# 2     153
# 3      97
# 5      79
# Name: count, dtype: int64
#
# [sex]
# sex
# Female    2631
# Male      2169
# Name: count, dtype: int64
#
# [med_change_flag]
# med_change_flag
# No     2540
# Yes    2260
# Name: count, dtype: int64
#
# [drug_014]
# drug_014
# absent      3864
# constant     856
# increase      52
# decrease      28
# Name: count, dtype: int64
#
# [drug_008]
# drug_008
# absent      4070
# constant     583
# increase      90
# decrease      57
# Name: count, dtype: int64
#
# [hba1c_result]
# hba1c_result
# NaN              3479
# high              528
# normal            436
# moderate high     357
# Name: count, dtype: int64
#
# [drug_015]
# drug_015
# absent      4260
# constant     433
# increase      64
# decrease      43
# Name: count, dtype: int64
#
# [on_diabetes_med]
# on_diabetes_med
# Yes    3651
# No     1149
# Name: count, dtype: int64
#
# [drug_017]
# drug_017
# absent      4421
# constant     350
# decrease      15
# increase      14
# Name: count, dtype: int64
#
# [drug_006]
# drug_006
# absent      4455
# constant     318
# increase      20
# decrease       7
# Name: count, dtype: int64
#
# [drug_020]
# drug_020
# absent      4500
# constant     237
# increase      42
# decrease      21
# Name: count, dtype: int64
#
# [max_glucose_level]
# max_glucose_level
# NaN          3375
# Norm          514
# High          463
# Very High     448
# Name: count, dtype: int64
#
# [readmission_status]
# readmission_status
# not_readmitted      2402
# readmitted_late     1627
# readmitted_early     771
# Name: count, dtype: int64
#
# Numerical Summary:
#        lab_test_count  medication_count  stay_duration_days  inpatient_visits  \
# count     4800.000000       4800.000000         4800.000000       4800.000000
# mean        45.027083         20.663125            5.860833          1.887083
# std         23.967073         14.950556            3.917918          3.397865
# min          0.000000          0.000000            1.000000         -1.000000
# 25%         28.000000         11.000000            3.000000          0.000000
# 50%         45.000000         16.000000            5.000000          0.000000
# 75%         61.000000         26.000000            9.000000          2.000000
# max        101.000000         81.000000           14.000000         15.000000
#
#        exit_status_code  diagnosis_count  procedure_count  entry_type_code  \
# count       4800.000000      4800.000000      4800.000000      4800.000000
# mean           7.644375         6.559792         1.301667         3.306667
# std            8.207356         4.001480         1.691280         2.408855
# min            0.000000         1.000000        -1.000000         0.000000
# 25%            1.000000         3.000000         0.000000         1.000000
# 50%            3.000000         6.000000         1.000000         3.000000
# 75%           13.000000         9.000000         2.000000         5.000000
# max           28.000000        16.000000         7.000000         8.000000
#
#        entry_origin_code  outpatient_visits  emergency_visits
# count        4800.000000        4800.000000       4800.000000
# mean            6.588958           1.601458          1.915625
# std             5.460766           3.603285          4.590522
# min             0.000000          -1.000000         -1.000000
# 25%             1.000000           0.000000          0.000000
# 50%             7.000000           0.000000          0.000000
# 75%             7.000000           1.000000          1.000000
# max            20.000000          16.000000         25.000000
#
# Categorical Summary:
#        secondary_diagnosis primary_diagnosis tertiary_diagnosis age_range  \
# count                 4800              4800               4800      4800
# unique                 356               378                368         5
# top                  DX310             DX310              DX306     60-80
# freq                    36               283                 27      1952
#
#        provider_specialty insurance_type_code drug_013 ethnic_group     sex  \
# count                4131                3404     4800         4276    4800
# unique                 48                  16        4            5       2
# top     Internal Medicine          provider_c   absent    Caucasian  Female
# freq                  222                1032     2204         1826    2631
#
#        med_change_flag drug_014 drug_008 hba1c_result drug_015  \
# count             4800     4800     4800         1321     4800
# unique               2        4        4            3        4
# top                 No   absent   absent         high   absent
# freq              2540     3864     4070          528     4260
#
#        on_diabetes_med drug_017 drug_006 drug_020 max_glucose_level  \
# count             4800     4800     4800     4800              1425
# unique               2        4        4        4                 3
# top                Yes   absent   absent   absent              Norm
# freq              3651     4421     4455     4500               514
#
#        readmission_status
# count                4800
# unique                  3
# top        not_readmitted
# freq                 2402
#
# ========================================
# Dataset: synthetic_data3.csv
# ========================================
# Shape: (4800, 31)
#
# Missing Values:
#                      MissingCount  MissingPct
# body_weight                  4752   99.000000
# hba1c_result                 4713   98.187500
# provider_specialty           2770   57.708333
# insurance_type_code          2020   42.083333
# ethnic_group                    7    0.145833
#
# Data Types:
# lab_test_count          int64
# primary_diagnosis      object
# secondary_diagnosis    object
# tertiary_diagnosis     object
# medication_count        int64
# inpatient_visits        int64
# stay_duration_days      int64
# age_range              object
# provider_specialty     object
# insurance_type_code    object
# diagnosis_count         int64
# exit_status_code        int64
# procedure_count         int64
# entry_type_code         int64
# drug_013               object
# entry_origin_code       int64
# ethnic_group           object
# outpatient_visits       int64
# emergency_visits        int64
# sex                    object
# drug_014               object
# hba1c_result           object
# med_change_flag        object
# drug_008               object
# drug_015               object
# on_diabetes_med        object
# drug_017               object
# drug_020               object
# drug_006               object
# body_weight            object
# readmission_status     object
# dtype: object
#
# Distinct Values per Column:
# tertiary_diagnosis     313
# primary_diagnosis      291
# secondary_diagnosis    280
# lab_test_count          97
# medication_count        55
# provider_specialty      39
# exit_status_code        17
# insurance_type_code     15
# stay_duration_days      14
# inpatient_visits        10
# entry_origin_code       10
# outpatient_visits        9
# diagnosis_count          8
# procedure_count          7
# entry_type_code          6
# emergency_visits         6
# body_weight              6
# age_range                5
# drug_013                 4
# drug_020                 4
# drug_008                 3
# hba1c_result             3
# ethnic_group             3
# readmission_status       3
# drug_015                 3
# sex                      2
# drug_014                 2
# med_change_flag          2
# on_diabetes_med          2
# drug_017                 2
# drug_006                 1
# dtype: int64
#
# Top-5 Frequent Values per Column:
#
# [lab_test_count]
# lab_test_count
# 1     135
# 37    110
# 40    102
# 39     95
# 43     90
# Name: count, dtype: int64
#
# [primary_diagnosis]
# primary_diagnosis
# DX310    528
# DX297    298
# DX600    225
# DX268    197
# DX293    190
# Name: count, dtype: int64
#
# [secondary_diagnosis]
# secondary_diagnosis
# DX110    450
# DX166    412
# DX309    322
# DX289    316
# DX310    259
# Name: count, dtype: int64
#
# [tertiary_diagnosis]
# tertiary_diagnosis
# DX110    967
# DX287    403
# DX166    399
# DX310    234
# DX448    170
# Name: count, dtype: int64
#
# [medication_count]
# medication_count
# 12    312
# 11    304
# 15    285
# 14    283
# 13    272
# Name: count, dtype: int64
#
# [inpatient_visits]
# inpatient_visits
# 0    4354
# 4     124
# 1     109
# 5      57
# 2      55
# Name: count, dtype: int64
#
# [stay_duration_days]
# stay_duration_days
# 3    886
# 2    660
# 4    586
# 1    560
# 5    547
# Name: count, dtype: int64
#
# [age_range]
# age_range
# 60-80    1988
# 40-60    1586
# 80+       932
# 20-40     261
# 0-20       33
# Name: count, dtype: int64
#
# [provider_specialty]
# provider_specialty
# NaN                   2770
# Internal Medicine      731
# Emergency Medicine     329
# Cardiologist           202
# Orthopedic Surgeon     127
# Name: count, dtype: int64
#
# [insurance_type_code]
# insurance_type_code
# NaN           2020
# provider_c    1922
# provider_b     203
# self_pay       184
# provider_a     184
# Name: count, dtype: int64
#
# [diagnosis_count]
# diagnosis_count
# 9    3201
# 5     555
# 6     388
# 3     229
# 7     183
# Name: count, dtype: int64
#
# [exit_status_code]
# exit_status_code
# 1     3502
# 3      686
# 6      382
# 20      53
# 21      41
# Name: count, dtype: int64
#
# [procedure_count]
# procedure_count
# 0    2407
# 1     814
# 3     625
# 2     412
# 4     294
# Name: count, dtype: int64
#
# [entry_type_code]
# entry_type_code
# 1    2460
# 3     946
# 2     915
# 6     265
# 5     206
# Name: count, dtype: int64
#
# [drug_013]
# drug_013
# absent      2310
# constant    1392
# decrease     572
# increase     526
# Name: count, dtype: int64
#
# [entry_origin_code]
# entry_origin_code
# 7     2740
# 1     1653
# 17     267
# 4       76
# 6       52
# Name: count, dtype: int64
#
# [ethnic_group]
# ethnic_group
# Caucasian          4305
# AfricanAmerican     483
# NaN                   7
# Asian                 5
# Name: count, dtype: int64
#
# [outpatient_visits]
# outpatient_visits
# 0    4400
# 2     126
# 1      83
# 3      73
# 5      58
# Name: count, dtype: int64
#
# [emergency_visits]
# emergency_visits
# 0    4620
# 1      79
# 3      76
# 4      19
# 2       5
# Name: count, dtype: int64
#
# [sex]
# sex
# Female    3116
# Male      1684
# Name: count, dtype: int64
#
# [drug_014]
# drug_014
# absent      4226
# constant     574
# Name: count, dtype: int64
#
# [hba1c_result]
# hba1c_result
# NaN              4713
# high               54
# normal             32
# moderate high       1
# Name: count, dtype: int64
#
# [med_change_flag]
# med_change_flag
# No     2597
# Yes    2203
# Name: count, dtype: int64
#
# [drug_008]
# drug_008
# absent      4732
# constant      57
# increase      11
# Name: count, dtype: int64
#
# [drug_015]
# drug_015
# absent      4783
# constant      16
# increase       1
# Name: count, dtype: int64
#
# [on_diabetes_med]
# on_diabetes_med
# Yes    3644
# No     1156
# Name: count, dtype: int64
#
# [drug_017]
# drug_017
# absent      4798
# constant       2
# Name: count, dtype: int64
#
# [drug_020]
# drug_020
# absent      4796
# constant       2
# decrease       1
# increase       1
# Name: count, dtype: int64
#
# [drug_006]
# drug_006
# absent    4800
# Name: count, dtype: int64
#
# [body_weight]
# body_weight
# NaN          4752
# [50-75)        17
# [100-125)      15
# [75-100)       13
# [150-175)       1
# Name: count, dtype: int64
#
# [readmission_status]
# readmission_status
# not_readmitted      3122
# readmitted_late     1611
# readmitted_early      67
# Name: count, dtype: int64
#
# Numerical Summary:
#        lab_test_count  medication_count  inpatient_visits  stay_duration_days  \
# count     4800.000000       4800.000000       4800.000000         4800.000000
# mean        43.845208         16.402083          0.318750            4.675833
# std         21.997907          7.737084          1.153766            2.880679
# min          1.000000          1.000000          0.000000            1.000000
# 25%         28.000000         11.000000          0.000000            2.000000
# 50%         44.000000         15.000000          0.000000            4.000000
# 75%         62.000000         20.000000          0.000000            7.000000
# max        101.000000         61.000000          9.000000           14.000000
#
#        diagnosis_count  exit_status_code  procedure_count  entry_type_code  \
# count      4800.000000       4800.000000      4800.000000      4800.000000
# mean          7.710833          2.504375         1.277708         2.044167
# std           1.976663          3.912033         1.670928         1.427459
# min           2.000000          1.000000         0.000000         1.000000
# 25%           6.000000          1.000000         0.000000         1.000000
# 50%           9.000000          1.000000         0.000000         1.000000
# 75%           9.000000          3.000000         2.000000         3.000000
# max           9.000000         24.000000         6.000000         8.000000
#
#        entry_origin_code  outpatient_visits  emergency_visits
# count        4800.000000        4800.000000       4800.000000
# mean            5.439792           0.235833          0.082917
# std             3.979647           0.899287          0.474171
# min             1.000000           0.000000          0.000000
# 25%             1.000000           0.000000          0.000000
# 50%             7.000000           0.000000          0.000000
# 75%             7.000000           0.000000          0.000000
# max            18.000000           8.000000          5.000000
#
# Categorical Summary:
#        primary_diagnosis secondary_diagnosis tertiary_diagnosis age_range  \
# count               4800                4800               4800      4800
# unique               291                 280                313         5
# top                DX310               DX110              DX110     60-80
# freq                 528                 450                967      1988
#
#        provider_specialty insurance_type_code drug_013 ethnic_group     sex  \
# count                2030                2780     4800         4793    4800
# unique                 39                  15        4            3       2
# top     Internal Medicine          provider_c   absent    Caucasian  Female
# freq                  731                1922     2310         4305    3116
#
#        drug_014 hba1c_result med_change_flag drug_008 drug_015  \
# count      4800           87            4800     4800     4800
# unique        2            3               2        3        3
# top      absent         high              No   absent   absent
# freq       4226           54            2597     4732     4783
#
#        on_diabetes_med drug_017 drug_020 drug_006 body_weight  \
# count             4800     4800     4800     4800          48
# unique               2        2        4        1           6
# top                Yes   absent   absent   absent     [50-75)
# freq              3644     4798     4796     4800          17
#
#        readmission_status
# count                4800
# unique                  3
# top        not_readmitted
# freq                 3122
#
# ========================================
# Dataset: synthetic_data4.csv
# ========================================
# Shape: (4800, 31)
#
# Missing Values:
#                      MissingCount  MissingPct
# body_weight                  4503   93.812500
# hba1c_result                 3718   77.458333
# provider_specialty           1793   37.354167
# insurance_type_code          1529   31.854167
# ethnic_group                  217    4.520833
#
# Data Types:
# lab_test_count          int64
# primary_diagnosis      object
# secondary_diagnosis    object
# tertiary_diagnosis     object
# medication_count        int64
# inpatient_visits        int64
# stay_duration_days      int64
# age_range              object
# provider_specialty     object
# insurance_type_code    object
# diagnosis_count         int64
# exit_status_code        int64
# procedure_count         int64
# entry_type_code         int64
# drug_013               object
# entry_origin_code       int64
# ethnic_group           object
# outpatient_visits       int64
# emergency_visits        int64
# sex                    object
# drug_014               object
# hba1c_result           object
# med_change_flag        object
# drug_008               object
# drug_015               object
# on_diabetes_med        object
# drug_017               object
# drug_020               object
# drug_006               object
# body_weight            object
# readmission_status     object
# dtype: object
#
# Distinct Values per Column:
# primary_diagnosis      253
# secondary_diagnosis    246
# tertiary_diagnosis     241
# lab_test_count         100
# medication_count        60
# provider_specialty      42
# exit_status_code        26
# insurance_type_code     16
# stay_duration_days      15
# entry_origin_code       13
# inpatient_visits        11
# outpatient_visits       10
# diagnosis_count          9
# entry_type_code          9
# procedure_count          8
# body_weight              8
# emergency_visits         6
# ethnic_group             5
# age_range                5
# drug_013                 4
# drug_014                 4
# drug_008                 4
# drug_017                 4
# drug_006                 4
# drug_020                 4
# drug_015                 4
# hba1c_result             3
# readmission_status       3
# sex                      2
# med_change_flag          2
# on_diabetes_med          2
# dtype: int64
#
# Top-5 Frequent Values per Column:
#
# [lab_test_count]
# lab_test_count
# 1     320
# 35     94
# 38     91
# 42     88
# 25     87
# Name: count, dtype: int64
#
# [primary_diagnosis]
# primary_diagnosis
# DX293    301
# DX363    227
# DX310    200
# DX297    188
# DX600    158
# Name: count, dtype: int64
#
# [secondary_diagnosis]
# secondary_diagnosis
# DX310    269
# DX112    269
# DX309    258
# DX110    243
# DX166    213
# Name: count, dtype: int64
#
# [tertiary_diagnosis]
# tertiary_diagnosis
# DX110    378
# DX287    304
# DX297    269
# DX310    256
# DX166    179
# Name: count, dtype: int64
#
# [medication_count]
# medication_count
# 13    301
# 14    289
# 15    277
# 16    274
# 12    260
# Name: count, dtype: int64
#
# [inpatient_visits]
# inpatient_visits
# 0    3815
# 1     424
# 2     359
# 3     100
# 5      46
# Name: count, dtype: int64
#
# [stay_duration_days]
# stay_duration_days
# 4    766
# 1    752
# 2    585
# 3    479
# 5    446
# Name: count, dtype: int64
#
# [age_range]
# age_range
# 60-80    3260
# 40-60     746
# 80+       425
# 20-40     284
# 0-20       85
# Name: count, dtype: int64
#
# [provider_specialty]
# provider_specialty
# NaN                   1793
# Internal Medicine      963
# Cardiologist           448
# Emergency Medicine     426
# General Surgeon        263
# Name: count, dtype: int64
#
# [insurance_type_code]
# insurance_type_code
# NaN             1529
# provider_c      1276
# provider_a       773
# provider_b       292
# managed_care     291
# Name: count, dtype: int64
#
# [diagnosis_count]
# diagnosis_count
# 9    1810
# 6    1159
# 7     567
# 8     384
# 4     381
# Name: count, dtype: int64
#
# [exit_status_code]
# exit_status_code
# 1    3962
# 6     262
# 2     203
# 5     115
# 3      96
# Name: count, dtype: int64
#
# [procedure_count]
# procedure_count
# 0    2139
# 2     745
# 3     498
# 1     491
# 6     445
# Name: count, dtype: int64
#
# [entry_type_code]
# entry_type_code
# 1    3394
# 2     513
# 3     431
# 6     272
# 5     152
# Name: count, dtype: int64
#
# [drug_013]
# drug_013
# absent      2399
# constant     965
# decrease     869
# increase     567
# Name: count, dtype: int64
#
# [entry_origin_code]
# entry_origin_code
# 1     2505
# 7     1787
# 17      92
# 4       67
# 16      65
# Name: count, dtype: int64
#
# [ethnic_group]
# ethnic_group
# Caucasian          3429
# AfricanAmerican     883
# NaN                 217
# Other               132
# Hispanic             84
# Name: count, dtype: int64
#
# [outpatient_visits]
# outpatient_visits
# 0    3170
# 1    1209
# 2     213
# 4      75
# 3      57
# Name: count, dtype: int64
#
# [emergency_visits]
# emergency_visits
# 0    4537
# 1     196
# 2      29
# 3      17
# 5      12
# Name: count, dtype: int64
#
# [sex]
# sex
# Female    2700
# Male      2100
# Name: count, dtype: int64
#
# [drug_014]
# drug_014
# absent      4343
# constant     348
# increase      56
# decrease      53
# Name: count, dtype: int64
#
# [hba1c_result]
# hba1c_result
# NaN              3718
# high              688
# normal            223
# moderate high     171
# Name: count, dtype: int64
#
# [med_change_flag]
# med_change_flag
# No     3469
# Yes    1331
# Name: count, dtype: int64
#
# [drug_008]
# drug_008
# absent      4413
# constant     244
# increase      76
# decrease      67
# Name: count, dtype: int64
#
# [drug_015]
# drug_015
# absent      3967
# constant     695
# increase      85
# decrease      53
# Name: count, dtype: int64
#
# [on_diabetes_med]
# on_diabetes_med
# Yes    4123
# No      677
# Name: count, dtype: int64
#
# [drug_017]
# drug_017
# absent      3743
# constant     984
# increase      56
# decrease      17
# Name: count, dtype: int64
#
# [drug_020]
# drug_020
# absent      4531
# constant     186
# increase      49
# decrease      34
# Name: count, dtype: int64
#
# [drug_006]
# drug_006
# absent      4213
# constant     526
# increase      49
# decrease      12
# Name: count, dtype: int64
#
# [body_weight]
# body_weight
# NaN          4503
# [75-100)      118
# [50-75)        60
# [100-125)      56
# [125-150)      19
# Name: count, dtype: int64
#
# [readmission_status]
# readmission_status
# not_readmitted      3065
# readmitted_late     1377
# readmitted_early     358
# Name: count, dtype: int64
#
# Numerical Summary:
#        lab_test_count  medication_count  inpatient_visits  stay_duration_days  \
# count     4800.000000       4800.000000       4800.000000         4800.000000
# mean        33.404792         15.381458          0.415000            4.926458
# std         21.199813          7.643284          1.031219            3.259718
# min          1.000000          1.000000          0.000000            0.000000
# 25%         16.000000         10.000000          0.000000            2.000000
# 50%         33.000000         15.000000          0.000000            4.000000
# 75%         49.000000         19.000000          0.000000            7.000000
# max        101.000000         65.000000         10.000000           14.000000
#
#        diagnosis_count  exit_status_code  procedure_count  entry_type_code  \
# count      4800.000000       4800.000000      4800.000000      4800.000000
# mean          7.080625          1.760208         1.824792         1.725208
# std           1.840583          2.385839         2.190246         1.437635
# min           1.000000          0.000000         0.000000         0.000000
# 25%           6.000000          1.000000         0.000000         1.000000
# 50%           7.000000          1.000000         1.000000         1.000000
# 75%           9.000000          1.000000         3.000000         2.000000
# max           9.000000         26.000000         7.000000         8.000000
#
#        entry_origin_code  outpatient_visits  emergency_visits
# count        4800.000000        4800.000000       4800.000000
# mean            4.138125           0.531250          0.083542
# std             3.997379           1.030208          0.427123
# min             0.000000           0.000000          0.000000
# 25%             1.000000           0.000000          0.000000
# 50%             1.000000           0.000000          0.000000
# 75%             7.000000           1.000000          0.000000
# max            19.000000           9.000000          5.000000
#
# Categorical Summary:
#        primary_diagnosis secondary_diagnosis tertiary_diagnosis age_range  \
# count               4800                4800               4800      4800
# unique               253                 246                241         5
# top                DX293               DX310              DX110     60-80
# freq                 301                 269                378      3260
#
#        provider_specialty insurance_type_code drug_013 ethnic_group     sex  \
# count                3007                3271     4800         4583    4800
# unique                 42                  16        4            5       2
# top     Internal Medicine          provider_c   absent    Caucasian  Female
# freq                  963                1276     2399         3429    2700
#
#        drug_014 hba1c_result med_change_flag drug_008 drug_015  \
# count      4800         1082            4800     4800     4800
# unique        4            3               2        4        4
# top      absent         high              No   absent   absent
# freq       4343          688            3469     4413     3967
#
#        on_diabetes_med drug_017 drug_020 drug_006 body_weight  \
# count             4800     4800     4800     4800         297
# unique               2        4        4        4           8
# top                Yes   absent   absent   absent    [75-100)
# freq              4123     3743     4531     4213         118
#
#        readmission_status
# count                4800
# unique                  3
# top        not_readmitted
# freq                 3065
#
# ========================================
# Dataset: test_data_with_outliers.csv
# ========================================
# Shape: (96, 32)
#
# Missing Values:
#                      MissingCount  MissingPct
# hba1c_result                   85   88.541667
# max_glucose_level              78   81.250000
# insurance_type_code            49   51.041667
# provider_specialty             48   50.000000
# ethnic_group                    1    1.041667
#
# Data Types:
# lab_test_count          int64
# secondary_diagnosis    object
# primary_diagnosis      object
# tertiary_diagnosis     object
# medication_count        int64
# stay_duration_days      int64
# inpatient_visits        int64
# age_range              object
# provider_specialty     object
# exit_status_code        int64
# insurance_type_code    object
# diagnosis_count         int64
# procedure_count         int64
# drug_013               object
# entry_type_code         int64
# entry_origin_code       int64
# ethnic_group           object
# outpatient_visits       int64
# emergency_visits        int64
# sex                    object
# med_change_flag        object
# drug_014               object
# drug_008               object
# hba1c_result           object
# drug_015               object
# on_diabetes_med        object
# drug_017               object
# drug_006               object
# drug_020               object
# max_glucose_level      object
# readmission_status     object
# is_member              object
# dtype: object
#
# Distinct Values per Column:
# lab_test_count         58
# secondary_diagnosis    54
# primary_diagnosis      53
# tertiary_diagnosis     47
# medication_count       35
# stay_duration_days     12
# exit_status_code       12
# provider_specialty     11
# insurance_type_code    11
# inpatient_visits       10
# entry_origin_code      10
# outpatient_visits      10
# diagnosis_count         9
# procedure_count         8
# emergency_visits        8
# entry_type_code         7
# age_range               5
# drug_013                4
# ethnic_group            3
# hba1c_result            3
# max_glucose_level       3
# readmission_status      3
# sex                     2
# med_change_flag         2
# drug_008                2
# drug_014                2
# drug_015                2
# on_diabetes_med         2
# drug_006                2
# drug_017                2
# drug_020                2
# is_member               2
# dtype: int64
#
# Top-5 Frequent Values per Column:
#
# [lab_test_count]
# lab_test_count
# 41    3
# 17    3
# 46    3
# 1     3
# 42    3
# Name: count, dtype: int64
#
# [secondary_diagnosis]
# secondary_diagnosis
# DX310    7
# DX166    6
# DX134    4
# DX387    4
# DX289    4
# Name: count, dtype: int64
#
# [primary_diagnosis]
# primary_diagnosis
# DX310    11
# DX297     7
# DX293     6
# DX600     5
# DX594     3
# Name: count, dtype: int64
#
# [tertiary_diagnosis]
# tertiary_diagnosis
# DX110    16
# DX166    10
# DX287     6
# DX448     5
# DX367     4
# Name: count, dtype: int64
#
# [medication_count]
# medication_count
# 13    10
# 15     6
# 17     6
# 11     6
# 20     6
# Name: count, dtype: int64
#
# [stay_duration_days]
# stay_duration_days
# 4    18
# 1    17
# 2    15
# 3     9
# 5     6
# Name: count, dtype: int64
#
# [inpatient_visits]
# inpatient_visits
# 0    46
# 1    17
# 4     9
# 2     7
# 3     4
# Name: count, dtype: int64
#
# [age_range]
# age_range
# 60-80    47
# 40-60    26
# 80+      14
# 20-40     7
# 0-20      2
# Name: count, dtype: int64
#
# [provider_specialty]
# provider_specialty
# NaN                   48
# Internal Medicine     15
# Cardiologist           9
# Emergency Medicine     8
# Family Practice        6
# Name: count, dtype: int64
#
# [exit_status_code]
# exit_status_code
# 1     37
# 6     16
# 25    15
# 3     10
# 22     5
# Name: count, dtype: int64
#
# [insurance_type_code]
# insurance_type_code
# NaN             49
# provider_c      22
# managed_care     6
# self_pay         5
# provider_a       5
# Name: count, dtype: int64
#
# [diagnosis_count]
# diagnosis_count
# 9    46
# 8    15
# 7    15
# 6     7
# 5     5
# Name: count, dtype: int64
#
# [procedure_count]
# procedure_count
# 0    35
# 1    17
# 6    14
# 2    10
# 3     8
# Name: count, dtype: int64
#
# [drug_013]
# drug_013
# absent      42
# constant    22
# decrease    17
# increase    15
# Name: count, dtype: int64
#
# [entry_type_code]
# entry_type_code
# 1    33
# 6    22
# 2    15
# 3    14
# 5    10
# Name: count, dtype: int64
#
# [entry_origin_code]
# entry_origin_code
# 7     43
# 17    25
# 1     19
# 4      3
# 20     1
# Name: count, dtype: int64
#
# [ethnic_group]
# ethnic_group
# Caucasian          76
# AfricanAmerican    15
# Hispanic            4
# NaN                 1
# Name: count, dtype: int64
#
# [outpatient_visits]
# outpatient_visits
# 0    55
# 1    15
# 3    11
# 2     5
# 5     4
# Name: count, dtype: int64
#
# [emergency_visits]
# emergency_visits
# 0    58
# 2    11
# 1     9
# 3     6
# 4     5
# Name: count, dtype: int64
#
# [sex]
# sex
# Female    56
# Male      40
# Name: count, dtype: int64
#
# [med_change_flag]
# med_change_flag
# No     48
# Yes    48
# Name: count, dtype: int64
#
# [drug_014]
# drug_014
# absent      75
# constant    21
# Name: count, dtype: int64
#
# [drug_008]
# drug_008
# absent      85
# constant    11
# Name: count, dtype: int64
#
# [hba1c_result]
# hba1c_result
# NaN              85
# normal            6
# high              3
# moderate high     2
# Name: count, dtype: int64
#
# [drug_015]
# drug_015
# absent      89
# constant     7
# Name: count, dtype: int64
#
# [on_diabetes_med]
# on_diabetes_med
# Yes    76
# No     20
# Name: count, dtype: int64
#
# [drug_017]
# drug_017
# absent      88
# constant     8
# Name: count, dtype: int64
#
# [drug_006]
# drug_006
# absent      88
# constant     8
# Name: count, dtype: int64
#
# [drug_020]
# drug_020
# absent      93
# constant     3
# Name: count, dtype: int64
#
# [max_glucose_level]
# max_glucose_level
# NaN          78
# Norm          7
# High          7
# Very High     4
# Name: count, dtype: int64
#
# [readmission_status]
# readmission_status
# not_readmitted      41
# readmitted_late     39
# readmitted_early    16
# Name: count, dtype: int64
#
# [is_member]
# is_member
# no     48
# yes    48
# Name: count, dtype: int64
#
# Numerical Summary:
#        lab_test_count  medication_count  stay_duration_days  inpatient_visits  \
# count       96.000000         96.000000           96.000000         96.000000
# mean        40.135417         17.729167            4.812500          1.833333
# std         21.750557         10.311444            3.543155          2.693722
# min          1.000000          1.000000            1.000000          0.000000
# 25%         22.000000         11.000000            2.000000          0.000000
# 50%         40.500000         15.000000            4.000000          1.000000
# 75%         55.250000         21.000000            7.000000          3.000000
# max         87.000000         60.000000           13.000000         11.000000
#
#        exit_status_code  diagnosis_count  procedure_count  entry_type_code  \
# count         96.000000        96.000000        96.000000        96.000000
# mean           7.979167         7.677083         2.010417         3.072917
# std            9.066978         1.803475         2.217133         2.098846
# min            1.000000         2.000000        -1.000000         0.000000
# 25%            1.000000         7.000000         0.000000         1.000000
# 50%            3.000000         8.000000         1.000000         2.000000
# 75%           11.000000         9.000000         4.000000         5.000000
# max           25.000000        10.000000         6.000000         8.000000
#
#        entry_origin_code  outpatient_visits  emergency_visits
# count          96.000000          96.000000         96.000000
# mean            8.427083           1.281250          1.406250
# std             5.960828           2.174992          2.697282
# min             0.000000           0.000000          0.000000
# 25%             4.750000           0.000000          0.000000
# 50%             7.000000           0.000000          0.000000
# 75%            17.000000           2.000000          2.000000
# max            20.000000          12.000000         16.000000
#
# Categorical Summary:
#        secondary_diagnosis primary_diagnosis tertiary_diagnosis age_range  \
# count                   96                96                 96        96
# unique                  54                53                 47         5
# top                  DX310             DX310              DX110     60-80
# freq                     7                11                 16        47
#
#        provider_specialty insurance_type_code drug_013 ethnic_group     sex  \
# count                  48                  47       96           95      96
# unique                 11                  11        4            3       2
# top     Internal Medicine          provider_c   absent    Caucasian  Female
# freq                   15                  22       42           76      56
#
#        med_change_flag  ... drug_008 hba1c_result drug_015 on_diabetes_med  \
# count               96  ...       96           11       96              96
# unique               2  ...        2            3        2               2
# top                 No  ...   absent       normal   absent             Yes
# freq                48  ...       85            6       89              76
#
#        drug_017 drug_006 drug_020 max_glucose_level readmission_status  \
# count        96       96       96                18                 96
# unique        2        2        2                 3                  3
# top      absent   absent   absent              Norm     not_readmitted
# freq         88       88       93                 7                 41
#
#        is_member
# count         96
# unique         2
# top           no
# freq          48
#
# [4 rows x 21 columns]
#
# ========================================
# Dataset: test_data_wto_outliers.csv
# ========================================
# Shape: (40, 32)
#
# Missing Values:
#                      MissingCount  MissingPct
# max_glucose_level              39        97.5
# hba1c_result                   33        82.5
# insurance_type_code            17        42.5
# provider_specialty             13        32.5
#
# Data Types:
# lab_test_count          int64
# secondary_diagnosis    object
# primary_diagnosis      object
# tertiary_diagnosis     object
# medication_count        int64
# stay_duration_days      int64
# inpatient_visits        int64
# age_range              object
# provider_specialty     object
# exit_status_code        int64
# insurance_type_code    object
# diagnosis_count         int64
# procedure_count         int64
# drug_013               object
# entry_type_code         int64
# entry_origin_code       int64
# ethnic_group           object
# outpatient_visits       int64
# emergency_visits        int64
# sex                    object
# med_change_flag        object
# drug_014               object
# drug_008               object
# hba1c_result           object
# drug_015               object
# on_diabetes_med        object
# drug_017               object
# drug_006               object
# drug_020               object
# max_glucose_level      object
# readmission_status     object
# is_member              object
# dtype: object
#
# Distinct Values per Column:
# primary_diagnosis      30
# lab_test_count         29
# secondary_diagnosis    27
# tertiary_diagnosis     24
# medication_count       22
# stay_duration_days      9
# exit_status_code        9
# provider_specialty      9
# diagnosis_count         8
# insurance_type_code     7
# entry_origin_code       7
# procedure_count         6
# entry_type_code         6
# age_range               5
# inpatient_visits        4
# drug_013                4
# ethnic_group            3
# outpatient_visits       3
# emergency_visits        3
# hba1c_result            3
# readmission_status      3
# sex                     2
# drug_014                2
# med_change_flag         2
# drug_008                2
# drug_015                2
# drug_017                2
# on_diabetes_med         2
# is_member               2
# drug_020                2
# drug_006                1
# max_glucose_level       1
# dtype: int64
#
# Top-5 Frequent Values per Column:
#
# [lab_test_count]
# lab_test_count
# 40    3
# 46    3
# 49    2
# 52    2
# 39    2
# Name: count, dtype: int64
#
# [secondary_diagnosis]
# secondary_diagnosis
# DX166    5
# DX310    5
# DX110    3
# DX196    2
# DX294    2
# Name: count, dtype: int64
#
# [primary_diagnosis]
# primary_diagnosis
# DX778    3
# DX310    3
# DX115    2
# DX293    2
# DX309    2
# Name: count, dtype: int64
#
# [tertiary_diagnosis]
# tertiary_diagnosis
# DX110    6
# DX287    5
# DX166    5
# DX310    3
# DX309    2
# Name: count, dtype: int64
#
# [medication_count]
# medication_count
# 10    4
# 11    4
# 13    3
# 16    3
# 19    3
# Name: count, dtype: int64
#
# [stay_duration_days]
# stay_duration_days
# 2    10
# 3    10
# 5     5
# 4     5
# 1     3
# Name: count, dtype: int64
#
# [inpatient_visits]
# inpatient_visits
# 0    32
# 1     6
# 3     1
# 2     1
# Name: count, dtype: int64
#
# [age_range]
# age_range
# 60-80    17
# 40-60    10
# 80+       8
# 20-40     3
# 0-20      2
# Name: count, dtype: int64
#
# [provider_specialty]
# provider_specialty
# NaN                   13
# Cardiologist          10
# Internal Medicine      8
# Family Practice        2
# Emergency Medicine     2
# Name: count, dtype: int64
#
# [exit_status_code]
# exit_status_code
# 1     25
# 6      6
# 11     2
# 3      2
# 5      1
# Name: count, dtype: int64
#
# [insurance_type_code]
# insurance_type_code
# NaN             17
# provider_c      13
# provider_b       3
# no_insurance     2
# self_pay         2
# Name: count, dtype: int64
#
# [diagnosis_count]
# diagnosis_count
# 9    15
# 6     7
# 8     7
# 7     4
# 3     3
# Name: count, dtype: int64
#
# [procedure_count]
# procedure_count
# 0    17
# 1    10
# 3     4
# 6     4
# 4     4
# Name: count, dtype: int64
#
# [drug_013]
# drug_013
# absent      22
# constant     8
# increase     6
# decrease     4
# Name: count, dtype: int64
#
# [entry_type_code]
# entry_type_code
# 1    20
# 2     7
# 3     7
# 5     3
# 6     2
# Name: count, dtype: int64
#
# [entry_origin_code]
# entry_origin_code
# 7     24
# 1      9
# 17     3
# 5      1
# 6      1
# Name: count, dtype: int64
#
# [ethnic_group]
# ethnic_group
# Caucasian          34
# AfricanAmerican     5
# Hispanic            1
# Name: count, dtype: int64
#
# [outpatient_visits]
# outpatient_visits
# 0    33
# 1     6
# 2     1
# Name: count, dtype: int64
#
# [emergency_visits]
# emergency_visits
# 0    37
# 1     2
# 2     1
# Name: count, dtype: int64
#
# [sex]
# sex
# Female    27
# Male      13
# Name: count, dtype: int64
#
# [med_change_flag]
# med_change_flag
# No     27
# Yes    13
# Name: count, dtype: int64
#
# [drug_014]
# drug_014
# absent      30
# constant    10
# Name: count, dtype: int64
#
# [drug_008]
# drug_008
# absent      38
# constant     2
# Name: count, dtype: int64
#
# [hba1c_result]
# hba1c_result
# NaN              33
# moderate high     3
# normal            3
# high              1
# Name: count, dtype: int64
#
# [drug_015]
# drug_015
# absent      38
# constant     2
# Name: count, dtype: int64
#
# [on_diabetes_med]
# on_diabetes_med
# Yes    27
# No     13
# Name: count, dtype: int64
#
# [drug_017]
# drug_017
# absent      38
# constant     2
# Name: count, dtype: int64
#
# [drug_006]
# drug_006
# absent    40
# Name: count, dtype: int64
#
# [drug_020]
# drug_020
# absent      39
# constant     1
# Name: count, dtype: int64
#
# [max_glucose_level]
# max_glucose_level
# NaN     39
# Norm     1
# Name: count, dtype: int64
#
# [readmission_status]
# readmission_status
# not_readmitted      23
# readmitted_late     13
# readmitted_early     4
# Name: count, dtype: int64
#
# [is_member]
# is_member
# yes    20
# no     20
# Name: count, dtype: int64
#
# Numerical Summary:
#        lab_test_count  medication_count  stay_duration_days  inpatient_visits  \
# count       40.000000         40.000000            40.00000         40.000000
# mean        41.800000         17.075000             3.82500          0.275000
# std         17.243654         10.737873             2.37387          0.640012
# min          1.000000          5.000000             1.00000          0.000000
# 25%         32.000000         10.000000             2.00000          0.000000
# 50%         43.000000         13.500000             3.00000          0.000000
# 75%         51.250000         19.250000             5.00000          0.000000
# max         80.000000         54.000000            13.00000          3.000000
#
#        exit_status_code  diagnosis_count  procedure_count  entry_type_code  \
# count         40.000000         40.00000        40.000000        40.000000
# mean           3.500000          7.12500         1.600000         2.050000
# std            4.706787          2.11451         1.997434         1.518265
# min            1.000000          1.00000         0.000000         0.000000
# 25%            1.000000          6.00000         0.000000         1.000000
# 50%            1.000000          8.00000         1.000000         1.000000
# 75%            5.250000          9.00000         3.000000         3.000000
# max           22.000000          9.00000         6.000000         6.000000
#
#        entry_origin_code  outpatient_visits  emergency_visits
# count          40.000000          40.000000         40.000000
# mean            6.075000           0.200000          0.100000
# std             4.091188           0.464095          0.378932
# min             0.000000           0.000000          0.000000
# 25%             3.250000           0.000000          0.000000
# 50%             7.000000           0.000000          0.000000
# 75%             7.000000           0.000000          0.000000
# max            17.000000           2.000000          2.000000
#
# Categorical Summary:
#        secondary_diagnosis primary_diagnosis tertiary_diagnosis age_range  \
# count                   40                40                 40        40
# unique                  27                30                 24         5
# top                  DX166             DX778              DX110     60-80
# freq                     5                 3                  6        17
#
#        provider_specialty insurance_type_code drug_013 ethnic_group     sex  \
# count                  27                  23       40           40      40
# unique                  9                   7        4            3       2
# top          Cardiologist          provider_c   absent    Caucasian  Female
# freq                   10                  13       22           34      27
#
#        med_change_flag  ... drug_008   hba1c_result drug_015 on_diabetes_med  \
# count               40  ...       40              7       40              40
# unique               2  ...        2              3        2               2
# top                 No  ...   absent  moderate high   absent             Yes
# freq                27  ...       38              3       38              27
#
#        drug_017 drug_006 drug_020 max_glucose_level readmission_status  \
# count        40       40       40                 1                 40
# unique        2        1        2                 1                  3
# top      absent   absent   absent              Norm     not_readmitted
# freq         38       40       39                 1                 23
#
#        is_member
# count         40
# unique         2
# top          yes
# freq          20
#
# [4 rows x 21 columns]

# %%
import os
import pandas as pd

LABEL_COLUMN = "is_member"

def load_columns(filepath, drop_label=False):
    df = pd.read_csv(filepath, nrows=1)  # Only read header
    cols = list(df.columns)
    if drop_label and LABEL_COLUMN in cols:
        cols.remove(LABEL_COLUMN)
    return set(cols)

def main():
    synthetic_columns = {}
    test_columns = {}

    # Load synthetic dataset columns
    for fname in SYNTHETIC_FILES:
        path = os.path.join(FOLDER_PATH, fname)
        try:
            synthetic_columns[fname] = load_columns(path)
        except Exception as e:
            print(f"Error reading {fname}: {e}")

    # Load test dataset columns (excluding label)
    for fname in TEST_FILES:
        path = os.path.join(FOLDER_PATH, fname)
        try:
            test_columns[fname] = load_columns(path, drop_label=True)
        except Exception as e:
            print(f"Error reading {fname}: {e}")

    print("\n=== Checking Synthetic Dataset Column Consistency ===")
    ref_cols = next(iter(synthetic_columns.values()))
    for fname, cols in synthetic_columns.items():
        if cols != ref_cols:
            diff = sorted(ref_cols.symmetric_difference(cols))
            print(f"❌ {fname} differs from others. Difference: {diff}")
        else:
            print(f"✅ {fname} matches reference synthetic schema.")

    print("\n=== Comparing Test Datasets to Synthetic Columns ===")
    for fname, cols in test_columns.items():
        if cols != ref_cols:
            diff = sorted(ref_cols.symmetric_difference(cols))
            print(f"❌ {fname} differs from synthetic schema. Difference: {diff}")
        else:
            print(f"✅ {fname} matches synthetic schema.")

if __name__ == "__main__":
    main()
# Out:
# === Checking Synthetic Dataset Column Consistency ===
# ✅ synthetic_data1.csv matches reference synthetic schema.
# ❌ synthetic_data2.csv differs from others. Difference: ['body_weight', 'max_glucose_level']
# ✅ synthetic_data3.csv matches reference synthetic schema.
# ✅ synthetic_data4.csv matches reference synthetic schema.
#
# === Comparing Test Datasets to Synthetic Columns ===
# ❌ test_data_with_outliers.csv differs from synthetic schema. Difference: ['body_weight', 'max_glucose_level']
# ❌ test_data_wto_outliers.csv differs from synthetic schema. Difference: ['body_weight', 'max_glucose_level']
